# %% [markdown]
# <a href="https://colab.research.google.com/github/kryzlerahne/IT3205_PhilippineDataAlliance/blob/main/Codes/The_Future_Pay_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Summary of Daily Minimum Wage Rate in the Philippines (2022)
# *Source: Philippine Statistics Authority*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Current%20Real%20MW%20February%202022.csv'
df = pd.read_csv(url)
newdf = df.drop([0,1,2], axis=0)
newdf.rename(columns={'Current Real Minimum Wage Based on February 2022 CPI (2018=100)': 'Region','Unnamed: 1': 'NonAgriculture', 'Unnamed: 2': 'AgriculturePlantation', 'Unnamed: 3': 'AgricultureNonPlantation'}, inplace=True)

display(newdf.iloc[0:])
# Out:
#     Region NonAgriculture AgriculturePlantation AgricultureNonPlantation
# 3      NCR         494.02                459.98                   459.98
# 4      CAR          312.5                 312.5                    312.5
# 5        I         304.39                 264.1                   252.46
# 6       II         326.57                 304.5                    304.5
# 7      III          370.7                344.22                    330.1
# 8     IV-A         355.87                330.96                   330.96
# 9     IV-B         275.39                275.39                   275.39
# 10       V         266.09                266.09                   266.09
# 11      VI         351.42                280.25                   280.25
# 12     VII         371.32                362.13                   362.13
# 13    VIII         287.36                260.83                   260.83
# 14      IX         288.32                276.46                   276.46
# 15       X         322.72                312.11                   312.11
# 16      XI         355.48                350.99                   350.99
# 17     XII            295                276.56                   276.56
# 18  CARAGA          281.2                 281.2                    281.2
# 19   BARMM         292.79                270.27                   270.27

# %%
#converting datatype
newdf['NonAgriculture']= newdf.NonAgriculture.astype(float)
newdf['AgriculturePlantation']= newdf.AgriculturePlantation.astype(float)
newdf['AgricultureNonPlantation']= newdf.AgricultureNonPlantation.astype(float)

# %%
#getting all values from the dataframe/csv

Region = newdf["Region"]
NonAgriculture = newdf["NonAgriculture"]
AgriculturePlantation = newdf["AgriculturePlantation"]
AgricultureNonPlantation = newdf["AgricultureNonPlantation"]

#size of the entire graph
f = plt.figure()
f.set_figwidth(25)
f.set_figheight(10)

#creating visualizations
plt.ylabel("Minimum Wage 2022" , fontsize=15)
plt.xlabel("Regions", fontsize=15)
plt.title("Summary of Daily Minimum Wage Rate in the Philippines (2022)", fontweight="bold" , fontsize=20)

xpos = np.arange(len(Region))
barTry=0.25
plt.bar(xpos, NonAgriculture, color="blue", width = barTry, label='Non-Agriculture')
plt.bar(xpos+0.3, AgriculturePlantation, color="hotpink", width = barTry , label='Agriculture Plantation')
plt.bar(xpos+0.6, AgricultureNonPlantation, color="yellow", width = barTry , label='Agriculture Non-Plantation')

plt.xticks(xpos+0.3, ('NCR', 'CAR', 'I', 'II','III','IV-A', 'IV-B', 'V', 'VI','VII','VIII','IX', 'X','XI', 'XII', 'CARAGA','BARMM'), fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# # Current Minimum Wage and Inflation Rate per Region (2022)

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Daily%20Minimum%20Wage%20By%20Region.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#     Region  Current Wage  Real Wage  Inflation Rate (%)
# 0      NCR           537     486.85                 4.4
# 1      CAR           350     308.10                 6.3
# 2        I           340     298.77                 5.2
# 3       II           370     320.07                 4.6
# 4      III           420     363.95                 6.1
# 5     IV-A           400     351.19                 4.7
# 6     IV-B           320     273.04                 4.1
# 7        V           310     263.61                 4.2
# 8       VI           395     347.10                 4.9
# 9      VII           404     367.27                 5.4
# 10    VIII           325     284.09                 6.1
# 11      IX           316     284.43                 4.5
# 12       X           365     319.06                 4.6
# 13      XI           396     349.21                 5.3
# 14     XII           336     290.41                 4.2
# 15  CARAGA           320     278.02                 4.4
# 16   BARMM           325     289.66                 2.1

# %%
#getting all values from the dataframe/csv
Region = df["Region"]
currentWage = df["Current Wage"]
inflation = df["Inflation Rate (%)"]

#changing the size of the entire graph
f = plt.figure()
f.set_figwidth(23)
f.set_figheight(7)

#Plot
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(Region, currentWage, c=inflation, s=300, cmap='autumn')
plt.title("Current Minimum Wage Vs Inlfation Rate Per Region", fontweight="bold")

plt.colorbar()
plt.show()

# %% [markdown]
# # ASIAN Countries' Minimum Wage and Unemployment Rate
# *Source: Trading Economics*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Dataset%20for%20ASIAN%20countries.csv'
df = pd.read_csv(url)
#df1=df.sort_values(by=['Unemployment Rate (%)'], ascending=False)
display(df.iloc[0:])
# Out:
#                  Country  Unemployment Rate (%)  \
# 0                  Qatar                   0.10
# 1               Cambodia                   0.31
# 2                   Laos                   1.00
# 3               Thailand                   1.64
# 4                Myanmar                   1.79
# 5              Singapore                   2.20
# 6                 Kuwait                   2.30
# 7                Vietnam                   2.46
# 8                  Japan                   2.60
# 9            South Korea                   2.70
# 10            Kyrgyzstan                   2.90
# 11                 Macau                   3.50
# 12                Taiwan                   3.70
# 13                Israel                   3.80
# 14              Malaysia                   4.10
# 15             Sri Lanka                   4.60
# 16  United Arab Emirates                   5.00
# 17            Bangladesh                   5.30
# 18              Hongkong                   5.40
# 19             Indonesia                   5.83
# 20           Philippines                   5.80
# 21                 China                   6.10
# 22                Brunei                   8.40
#
#     Daily Minimum Wage in US Dollar
# 0                              9.15
# 1                              6.33
# 2                              3.99
# 3                             11.16
# 4                              2.59
# 5                            120.33
# 6                              6.53
# 7                              6.41
# 8                             76.38
# 9                             62.76
# 10                             8.41
# 11                            31.66
# 12                            46.03
# 13                            61.59
# 14                             9.91
# 15                             5.14
# 16                             9.02
# 17                             3.20
# 18                            38.69
# 19                             9.89
# 20                            10.28
# 21                            12.81
# 22                            19.58

# %%
#getting all values from the dataframe/csv
Country = df["Country"]
Rate = df["Unemployment Rate (%)"]
MinWage = df["Daily Minimum Wage in US Dollar"]

#size of the entire graph
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(8)

#creating visualization 1
plt.ylabel("Asian Countries")
plt.xlabel("Unemployment Rate Percentage")
plt.title("Unemployment Rate in ASIA (2020-2022)", fontweight="bold")
plt.barh(Country, Rate)
plt.show() 

#creating visualization 2
#f = plt.figure()
#f.set_figwidth(33)
#f.set_figheight(8)
#plt.xlabel("Asian Countries")
#plt.ylabel("Daily Minimum Wage in US Dollar")
#plt.title("Daily Minimum Wage in ASIAN Countries", fontweight="bold")
#plt.bar(Country, MinWage)
#plt.show()

# %% [markdown]
# # Unemployment Rate in the Philippines (2021-2022)
# *Source: Philippine Statistics Authority*
#
#
# *   The following provides information on the current unemployment rate present in the Philippines from year 2021-2022.

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Unemployment%20Rate.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#       Date  Percentage Thousands of People  Percentage Change
# 0   Feb-21        8.85               4,187               0.00
# 1   Mar-21        7.05               3,440             -17.84
# 2   Apr-21        8.73               4,137              20.27
# 3   May-21        7.70               3,730              -9.85
# 4   Jun-21        7.71               3,764               0.91
# 5   Jul-21        6.87               3,073             -18.36
# 6   Aug-21        8.07               3,882              26.32
# 7   Sep-21        8.89               4,254               9.60
# 8   Oct-21        7.40               3,503             -17.65
# 9   Nov-21        6.50               3,159              -9.83
# 10  Dec-21        6.60               3,271               3.57
# 11  Jan-22        6.37               2,925             -10.59
# 12  Feb-22        6.43               2,190             -25.11

# %%
#Visualization
#getting all values from the dataframe/csv
Date = df["Date"]
Percentage = df["Percentage"]

#changing the size of the entire graph
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(7)

#Creating plots
plt.title("\n Unemployment Rate in Philippines", fontweight="bold")
plt.xlabel("Reference Date")
plt.ylabel("Percentage")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.plot(Date, Percentage)
plt.show()

# %% [markdown]
# # Labor Force Employment (2021-2022)
# *Source: Philippine Statistics Authority*
#
#
# *   This will provide high frequency statistical information on the Philippine labor market to better understand the current situation of employment and the economy of the Philippines during unprecedented event such as the Corana Virus of 2019 (COVID-19) pandemic.

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Labor%20Force%20Employment%20(2021-2022).csv'
df = pd.read_csv(url)
display(df.iloc[0:, 0:3])
# Out:
#       Date  Thousands of People  Percentage Change
# 0   Feb-21                43153               0.00
# 1   Mar-21                45331               5.05
# 2   Apr-21                43269              -4.55
# 3   May-21                44715               3.34
# 4   Jun-21                45075               0.80
# 5   Jul-21                41667              -7.56
# 6   Aug-21                44233               6.16
# 7   Sep-21                43591              -1.45
# 8   Oct-21                43826               0.54
# 9   Nov-21                45477               3.77
# 10  Dec-21                46274               1.75
# 11  Jan-22                43018              -7.04
# 12  Feb-22                48606              12.99

# %%
#getting all the values stored in the dataframe/csv
Date = df["Date"]
People = df["Thousands of People"]

#changing the size of visualization
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(6)

#creating the plot
plt.plot(Date, People)
plt.title("\n Labor Force Employment in the Philippines (2021-2022)", fontweight="bold")
plt.xlabel("Reference Date")
plt.ylabel("Number of Population")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# # Inflation Rate in the Philippines (2019-2022)
# *Source: Philippine Statistics Authority*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Inflation%20Rates%20in%20PH.csv'
df = pd.read_csv(url)

new_df = df.drop([0,1], axis=0)
new_df.rename(columns={'Year on Year Inflation Rates in the Philippines (January 2019 - April 2022)': 'Month','Unnamed: 1': 'InflationRate2019', 'Unnamed: 2': 'InflationRate2020', 'Unnamed: 3': 'InflationRate2021', 'Unnamed: 4': 'InflationRate2022'}, inplace=True)

new_df['InflationRate2022'] = new_df['InflationRate2022'].fillna(0)

display(new_df)
# Out:
#         Month InflationRate2019  InflationRate2020  InflationRate2021  \
# 2     January               4.4                3.0                3.7
# 3    February               3.8                2.5                4.2
# 4       March               3.4                2.2                4.1
# 5       April               3.2                1.8                4.1
# 6         May               3.2                1.6                4.1
# 7        June               2.7                2.3                3.7
# 8        July               2.2                2.4                3.7
# 9      August               1.4                2.2                4.4
# 10  September               0.5                2.2                4.2
# 11    October               0.6                2.3                4.0
# 12   November               1.2                3.0                3.7
# 13   December               2.4                3.3                3.1
#
#     InflationRate2022
# 2                 3.0
# 3                 3.0
# 4                 4.0
# 5                 4.9
# 6                 0.0
# 7                 0.0
# 8                 0.0
# 9                 0.0
# 10                0.0
# 11                0.0
# 12                0.0
# 13                0.0

# %%
#converting datatype  
new_df['InflationRate2019']= new_df.InflationRate2019.astype(float)

#getting all values from the dataframe/csv
Month = new_df["Month"]
InflationRate2019 = new_df["InflationRate2019"]
InflationRate2020 = new_df["InflationRate2020"]
InflationRate2021 = new_df["InflationRate2021"]
InflationRate2022 = new_df["InflationRate2022"]

#changing the size of the entire graph
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(7)

#Creating plots
plt.title("Inflation Rate in Philippines 2019-2022", fontweight="bold")
plt.xlabel("Months")
plt.ylabel("Inflation Rate")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.plot(Month, InflationRate2019, color="blue", label="Inflation Rate 2019")
plt.plot(Month, InflationRate2020, color="red", label="Inflation Rate 2020")
plt.plot(Month, InflationRate2021, color="yellow", label="Inflation Rate 2021")
plt.plot(Month, InflationRate2022, color="orange", label="Inflation Rate 2022")
plt.legend()
plt.show()

# %% [markdown]
# # Labor Migration Rate in Philippines (2015-2020)

# %%
#Dataframe
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Labor%20Migration%20Rate.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#    Year  Millions of OFW Deployment  Net Migration Rate
# 0  2015                     1455000              -1.275
# 1  2016                     1689000              -1.062
# 2  2017                     1620000              -0.848
# 3  2018                     1540000              -0.634
# 4  2019                     2140000              -0.626
# 5  2020                     1771000              -0.618

# %%
#getting all the values stored in the dataframe/csv
Year = df["Year"]
People = df["Millions of OFW Deployment"]

#changing the size of visualization
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(6)

#creating the plot
plt.plot(Year, People)
plt.title("\n Labor Migration Rate in the Philippines", fontweight="bold")
plt.xlabel("Year")
plt.ylabel("Number of OFWs")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# # Poverty Statistics

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Poverty%20Incidence%20Rate.csv'
df = pd.read_csv(url)
display(df)
# Out:
#     Region  Poverty Incidence 2018  Poverty Incidence 2021
# 0      NCR                     4.9                     5.2
# 1      CAR                    13.8                    12.1
# 2        I                     8.7                    15.8
# 3       II                    15.3                    16.4
# 4      III                     7.9                    13.7
# 5     IV-A                     7.8                    10.6
# 6     IV-B                    15.1                    19.3
# 7        V                    21.5                    26.1
# 8       VI                    15.9                    19.2
# 9      VII                    19.1                    26.8
# 10    VIII                    30.4                    28.9
# 11      IX                    32.4                    30.9
# 12       X                    25.6                    26.2
# 13      XI                    17.8                    14.0
# 14     XII                    27.2                    27.1
# 15  CARAGA                    28.3                    31.0
# 16   BARMM                    55.9                    39.4

# %%
#getting all values from the dataframe/csv
Region = df["Region"]
PI2018 = df["Poverty Incidence 2018"]
PI2021 = df["Poverty Incidence 2021"]

#size of the entire graph
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)

#creating visualizations
plt.xlabel("Regions")
plt.ylabel("Poverty Instance Rate")
plt.title("\n Poverty Rate in the Philippines", fontweight="bold")

xpos = np.arange(len(Region))
barTry=0.3
plt.bar(xpos, PI2018,width=barTry, label='Poverty Incidence 2018')
plt.bar(xpos+0.3, PI2021, color="orange", width=barTry, label='Poverty Incidence 2021')
plt.xticks(xpos+0.1, ('NCR', 'CAR', 'I', 'II','III','IV-A', 'IV-B', 'V', 'VI','VII','VIII','IX', 'X','XI', 'XII', 'CARAGA','BARMM'))
plt.legend()
plt.show()

# %% [markdown]
# # Philippines Population Growth (2022)
# *Source: United Nations Data*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Population%20Growth%20Rate.csv'
df = pd.read_csv(url)
display(df)
# Out:
#    Year  Growth Rate   Estimated Total Population
# 0  2017          1.46                   105200000
# 1  2018          1.41                   106700000
# 2  2019          1.37                   108100000
# 3  2020          1.35                   109600000
# 4  2021          1.34                   111000000
# 5  2022          1.32                   112500000

# %%
#getting all the values stored in the dataframe/csv
Year = df["Year"]
People = df["Estimated Total Population"]

#changing the size of visualization
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(6)

#creating the plot
plt.plot(Year, People)
plt.title("\n Poverty Statistics in the Philippines", fontweight="bold")
plt.xlabel("Year")
plt.ylabel("Millions of Population")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# # Daily Expenditure Pattern of Filipinos
# *Source: 2018 PSA Survey*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Expenditure%20Pattern.csv'
df = pd.read_csv(url)
display(df)
# Out:
#                   Expense  % Allocation
# 0                    Food          58.2
# 1            House Rental           8.1
# 2               Utilities           7.6
# 3  Miscellaneous Expenses          20.9
# 4          Transportation           5.2

# %%
#getting all values from the dataframe/csv
Expense = df["Expense"]
Allocation = df["% Allocation"]

#changing the size of the entire graph
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(7)

#Creating Visualization
plt.pie(Allocation, labels=Expense, autopct='%1.2f%%', startangle=15, shadow = True)
plt.legend()
plt.show()

# %% [markdown]
# ### Minimum Wage Vs. Poverty

# %% [markdown]
# ### Minimum Wage Vs. Unemployment Rate

# %% [markdown]
# ### Minimum Wage Vs. Inflation Rate

# %% [markdown]
# ### Minimum Wage Vs. Labor Migration Rate
