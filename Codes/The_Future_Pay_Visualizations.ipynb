# %% [markdown]
# <a href="https://colab.research.google.com/github/kryzlerahne/IT3205_PhilippineDataAlliance/blob/main/Codes/The_Future_Pay_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Labor Force Employment (2021-2022)
# *Source: Philippine Statistics Authority*
#
#
# *   This will provide high frequency statistical information on the Philippine labor market to better understand the current situation of employment and the economy of the Philippines during unprecedented event such as the Corana Virus of 2019 (COVID-19) pandemic.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Employment%20and%20Unemployment%20Rate.csv'
df = pd.read_csv(url)
display(df.iloc[0:14, 0:3])
# Out:
#    Labor Force Employment (2021-2022)           Unnamed: 1         Unnamed: 2
# 0                                Date  Thousands of People  Percentage Change
# 1                              Feb-21              43, 153                  0
# 2                              Mar-21              45, 331               5.05
# 3                              Apr-21              43, 269              -4.55
# 4                              May-21              44, 715               3.34
# 5                              Jun-21              45, 075                0.8
# 6                              Jul-21              41, 667              -7.56
# 7                              Aug-21              44, 233               6.16
# 8                              Sep-21              43, 591              -1.45
# 9                              Oct-21              43, 826               0.54
# 10                             Nov-21              45, 477               3.77
# 11                             Dec-21              46, 274               1.75
# 12                             Jan-22              43, 018              -7.04
# 13                             Feb-22              48, 606              12.99

# %%
#Date = df["Labor Force Employment (2021-2022)"]
#People = df["Unnamed: 1"]
#x = list(Date)
#y = list(People)
#x=["Feb-21", "Mar-21", "Apr-21", "May-21", "June-21", "Jul-21", "Aug-21", "Sep-21", "Oct-21", "Nov-21", "Dec-21", "Jan-22", "Feb-22"]
#y=[43153, 45331, 43269, 44715, 45075, 41667, 44233, 43591, 43826, 45477, 46274, 43018, 48606]
#plt.plot(x,y)
#plt.show()

# %% [markdown]
# # Unemployment Rate (2021-2022)
# *Source: Philippine Statistics Authority*
#
#
# *   The following provides information on the current unemployment rate present in the Philippines from year 2021-2022.

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Employment%20and%20Unemployment%20Rate.csv'
df = pd.read_csv(url)
display(df.iloc[15:30])
# Out:
#    Labor Force Employment (2021-2022)  Unnamed: 1           Unnamed: 2  \
# 15      Unemployment Rate (2021-2022)         NaN                  NaN
# 16                               Date  Percentage  Thousands of People
# 17                             Feb-21        8.85                4,187
# 18                             Mar-21        7.05                3,440
# 19                             Apr-21        8.73                4,137
# 20                             May-21         7.7                3,730
# 21                             Jun-21        7.71                3,764
# 22                             Jul-21        6.87                3,073
# 23                             Aug-21        8.07                3,882
# 24                             Sep-21        8.89                4,254
# 25                             Oct-21         7.4                3,503
# 26                             Nov-21         6.5                3,159
# 27                             Dec-21         6.6                3,271
# 28                             Jan-22        6.37                2,925
# 29                             Feb-22        6.43                2,190
#
#            Unnamed: 3
# 15                NaN
# 16  Percentage Change
# 17                  0
# 18             -17.84
# 19              20.27
# 20              -9.85
# 21               0.91
# 22             -18.36
# 23              26.32
# 24                9.6
# 25             -17.65
# 26              -9.83
# 27               3.57
# 28             -10.59
# 29             -25.11

# %% [markdown]
# # Philippine Agriculture Employment (2021-2022)
# *Source: Philippine Statistics Authority*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Employment%20and%20Unemployment%20Rate.csv'
df = pd.read_csv(url)
display(df.iloc[32:46, 0:2])
# Out:
#    Labor Force Employment (2021-2022)                    Unnamed: 1
# 32                                NaN  Number of People/ Population
# 33                          Year 2005                    12,124,299
# 34                          Year 2006                    12,395,862
# 35                          Year 2007                    12,470,666
# 36                          Year 2008                    12,850,331
# 37                          Year 2009                    12,930,126
# 38                          Year 2010                    12,818,045
# 39                          Year 2011                    13,167,144
# 40                          Year 2012                    13,029,106
# 41                          Year 2013                    12,779,201
# 42                          Year 2014                    12,980,617
# 43                          Year 2015                    12,530,236
# 44                          Year 2016                    11,807,387
# 45                          Year 2017                    11,589,853

# %% [markdown]
# # Summary of Daily Minimum Wage Rate in the Philippines (2022)
# *Source: Philippine Statistics Authority*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Current%20Real%20MW%20February%202022.csv'
df = pd.read_csv(url)
display(df.iloc[1:21])
# Out:
#    Current Real Minimum Wage Based on February 2022 CPI (2018=100)  \
# 1                                              Region
# 2                                                 NaN
# 3                                                 NCR
# 4                                                 CAR
# 5                                                   I
# 6                                                  II
# 7                                                 III
# 8                                                IV-A
# 9                                                IV-B
# 10                                                  V
# 11                                                 VI
# 12                                                VII
# 13                                               VIII
# 14                                                 IX
# 15                                                  X
# 16                                                 XI
# 17                                                XII
# 18                                             CARAGA
# 19                                              BARMM
#
#          Unnamed: 1   Unnamed: 2      Unnamed: 3
# 1   Non-Agriculture  Agriculture             NaN
# 2               NaN   Plantation  Non-Plantation
# 3            494.02       459.98          459.98
# 4             312.5        312.5           312.5
# 5            304.39        264.1          252.46
# 6            326.57        304.5           304.5
# 7             370.7       344.22           330.1
# 8            355.87       330.96          330.96
# 9            275.39       275.39          275.39
# 10           266.09       266.09          266.09
# 11           351.42       280.25          280.25
# 12           371.32       362.13          362.13
# 13           287.36       260.83          260.83
# 14           288.32       276.46          276.46
# 15           322.72       312.11          312.11
# 16           355.48       350.99          350.99
# 17              295       276.56          276.56
# 18            281.2        281.2           281.2
# 19           292.79       270.27          270.27

# %% [markdown]
# # Minimum Wage Rates in Philippines (2016-2022)
# *Source:*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Minimum%20Wage%20in%20the%20Philippines%202016%2C%202018%2C%202021%2C%20%26%202022.csv'
df = pd.read_csv(url)
display(df.iloc[:])
# Out:
#    Minimum Wage Rates by Sector and Region, Philippines       Unnamed: 1  \
# 0                                              Region    Non-Agriculture
# 1                                                 NaN               2016
# 2                                                 NCR                481
# 3                                                 CAR                285
# 4                                                   I                253
# 5                                                  II                255
# 6                                                 III                364
# 7                                                IV-A              362.5
# 8                                                IV-B                285
# 9                                                   V                265
# 10                                                 VI              298.5
# 11                                                VII                353
# 12                                               VIII                260
# 13                                                 IX                280
# 14                                                  X                318
# 15                                                 XI                317
# 16                                                XII                275
# 17                                             CARAGA                268
# 18                                              BARMM                250
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4   Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0          NaN         NaN         NaN  Agriculture         NaN         NaN
# 1       2018.0      2021.0     2022.00         2016      2018.0      2021.0
# 2        512.0       537.0      494.02          444       475.0       500.0
# 3        300.0       350.0      312.50          270       300.0       350.0
# 4        280.0       340.0      304.39          233       252.0       295.0
# 5        340.0       370.0      326.57          243       320.0       345.0
# 6        380.0       420.0      370.70          334       350.0       390.0
# 7        378.5       400.0      355.57        337.5       353.5       372.0
# 8        290.0       320.0      275.39          235       290.0       320.0
# 9        290.0       310.0      266.09          248       290.0       310.0
# 10       323.5       395.0      351.42        266.5       281.5       315.0
# 11       366.0       404.0      371.32          335       348.0       394.0
# 12       285.0       325.0      287.36          241       251.0       295.0
# 13       296.0       316.0      288.32          255       283.0       303.0
# 14       338.0       365.0      322.72          306       326.0       353.0
# 15       340.0       396.0      355.48          307       335.0       391.0
# 16       295.0       336.0      295.00          257       272.0       315.0
# 17       290.0       320.0      281.20          268       290.0       320.0
# 18       265.0       325.0      292.79          250       255.0       300.0
#
#     Unnamed: 8
# 0          NaN
# 1      2022.00
# 2       459.98
# 3       312.50
# 4       264.10
# 5       304.50
# 6       344.22
# 7       330.96
# 8       275.39
# 9       266.09
# 10      280.25
# 11      362.13
# 12      260.83
# 13      276.46
# 14      312.11
# 15      350.99
# 16      276.56
# 17      281.20
# 18      270.27

# %% [markdown]
# # Inflation Rate in the Philippines (2019-2022)
# *Source: Philippine Statistics Authority*

# %%
url = 'https://raw.githubusercontent.com/kryzlerahne/IT3205_PhilippineDataAlliance/main/Datasets/Inflation%20Rates%20in%20PH.csv'
df = pd.read_csv(url)
display(df)
# Out:
#    Year on Year Inflation Rates in the Philippines (January 2019 - April 2022)  \
# 0                                               Month
# 1                                                 NaN
# 2                                             January
# 3                                            February
# 4                                               March
# 5                                               April
# 6                                                 May
# 7                                                June
# 8                                                July
# 9                                              August
# 10                                          September
# 11                                            October
# 12                                           November
# 13                                           December
#
#                    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0   Inflation Rate in percent         NaN         NaN         NaN
# 1                        2019      2020.0      2021.0      2022.0
# 2                         4.4         3.0         3.7         3.0
# 3                         3.8         2.5         4.2         3.0
# 4                         3.4         2.2         4.1         4.0
# 5                         3.2         1.8         4.1         4.9
# 6                         3.2         1.6         4.1         NaN
# 7                         2.7         2.3         3.7         NaN
# 8                         2.2         2.4         3.7         NaN
# 9                         1.4         2.2         4.4         NaN
# 10                        0.5         2.2         4.2         NaN
# 11                        0.6         2.3         4.0         NaN
# 12                        1.2         3.0         3.7         NaN
# 13                        2.4         3.3         3.1         NaN

# %% [markdown]
# # Poverty Statistics

# %% [markdown]
# # Increase in Minimum Wage Among Philippine Administrations

# %% [markdown]
# # Current Amount of Minimum Wages in Selected Countries (2022)
